# %%
# Just this time, I will include this already for you in your assignment
# INSTALL NUMPY AND MATPLOTLIB IF THEY ARE NOT ALREADY INSTALLED, FIRST
import numpy as np  # import numpy package 
import matplotlib.pyplot as plt # function in matplotlib that produces quick and easy plots

# %% [markdown]
# # Question 1:  Reading in and plotting data from a text file
# **Data**:
#   - tidal height (in cm) from the SYOWA Station, Antarctica on Dec 26, 2004, observed every 30 seconds
#
# **Context**:
#    - a magnitude ~9.1 earthquake occured off the coast of Sumatra, Indonesia, generating a series of devastating tsunami waves
#    - maximum wave height of 100 ft (!!), and noticeable effects thousands of miles away
#    - nearly 230,000 fatalities in total :(
#    - the motivation for the development of the Indian Ocean Tsunami Warning System
#
# **Further info for the interested**
#   - https://www.usgs.gov/centers/pcmsc/science/tsunami-generation-2004-m91-sumatra-andaman-earthquake?qt-science_center_objects=0#qt-science_center_objects (technical, but has some excellent animations!)

# %% [markdown]
# #### (a.)
# #### 1. Create a string variable consisting of 'heights.txt'
# #### 2.  Create another string variable consisting of '20041226_'
# #### 3.  Concatenate these two variables together and save in a new variable, such that your result is the name of file: 20041226_heights.txt

# %%
hgts = 'heights.txt'
date = '20041226_'
txt_string = date + hgts
print(txt_string)
# Out:
# 20041226_heights.txt

# %% [markdown]
# #### (b.)
# #### 1. Open the file '20041226_heights.txt' using your variable created in (a.), step 3.
# #### 2. Read the contents of this file into a list of strings
# #### 3. Close the file

# %%
f = open(f"/pscratch/sd/d/dbrooks/atms517/{txt_string}","r")
list_of_str = f.readlines()
f.close()

# %% [markdown]
# #### (c.)  Determine and print the type of the variable you created in (b.), step 2

# %%
print(type(list_of_str))
print(type(list_of_str[0]))
# Out:
# <class 'list'>
# <class 'str'>

# %% [markdown]
# #### (d.)  Print the values of this variable.

# %%
print(list_of_str)
# Out:
# ['1250\n', '1250\n', '1250\n', '1250\n', '1250\n', '1250\n', '1250\n', '1251\n', '1251\n', '1251\n', '1251\n', '1251\n', '1250\n', '1251\n', '1250\n', '1251\n', '1251\n', '1251\n', '1251\n', '1251\n', '1251\n', '1251\n', '1251\n', '1251\n', '1250\n', '1250\n', '1250\n', '1250\n', '1251\n', '1250\n', '1250\n', '1250\n', '1251\n', '1251\n', '1251\n', '1251\n', '1251\n', '1251\n', '1252\n', '1252\n', '1252\n', '1251\n', '1251\n', '1251\n', '1251\n', '1251\n', '1252\n', '1252\n', '1252\n', '1252\n', '1252\n', '1252\n', '1252\n', '1252\n', '1251\n', '1252\n', '1252\n', '1252\n', '1252\n', '1253\n', '1252\n', '1252\n', '1252\n', '1252\n', '1253\n', '1253\n', '1253\n', '1253\n', '1253\n', '1253\n', '1253\n', '1253\n', '1253\n', '1253\n', '1254\n', '1253\n', '1253\n', '1253\n', '1253\n', '1253\n', '1253\n', '1253\n', '1253\n', '1253\n', '1254\n', '1254\n', '1255\n', '1255\n', '1255\n', '1254\n', '1254\n', '1254\n', '1254\n', '1254\n', '1254\n', '1254\n', '1254\n', '1255\n', '1255\n', '1254\n', '1254\n', '1254\n', '1254\n', '1254\n', '1255\n', '1256\n', '1256\n', '1256\n', '1256\n', '1256\n', '1256\n', '1255\n', '1255\n', '1255\n', '1255\n', '1255\n', '1255\n', '1255\n', '1255\n', '1255\n', '1255\n', '1256\n', '1256\n', '1256\n', '1256\n', '1256\n', '1256\n', '1256\n', '1256\n', '1256\n', '1256\n', '1255\n', '1256\n', '1256\n', '1257\n', '1257\n', '1257\n', '1257\n', '1257\n', '1257\n', '1257\n', '1257\n', '1257\n', '1256\n', '1256\n', '1257\n', '1257\n', '1257\n', '1257\n', '1257\n', '1257\n', '1257\n', '1257\n', '1257\n', '1257\n', '1257\n', '1258\n', '1258\n', '1258\n', '1258\n', '1258\n', '1258\n', '1258\n', '1258\n', '1258\n', '1258\n', '1258\n', '1258\n', '1258\n', '1258\n', '1258\n', '1258\n', '1258\n', '1258\n', '1258\n', '1259\n', '1259\n', '1259\n', '1260\n', '1260\n', '1260\n', '1260\n', '1259\n', '1259\n', '1259\n', '1259\n', '1259\n', '1260\n', '1260\n', '1260\n', '1260\n', '1261\n', '1261\n', '1261\n', '1261\n', '1261\n', '1262\n', '1262\n', '1262\n', '1262\n', '1263\n', '1263\n', '1263\n', '1263\n', '1262\n', '1262\n', '1261\n', '1261\n', '1261\n', '1262\n', '1262\n', '1263\n', '1263\n', '1264\n', '1264\n', '1263\n', '1263\n', '1263\n', '1263\n', '1263\n', '1263\n', '1263\n', '1263\n', '1263\n', '1264\n', '1264\n', '1264\n', '1264\n', '1264\n', '1264\n', '1264\n', '1264\n', '1264\n', '1264\n', '1264\n', '1264\n', '1264\n', '1264\n', '1264\n', '1264\n', '1264\n', '1263\n', '1263\n', '1264\n', '1264\n', '1265\n', '1265\n', '1265\n', '1265\n', '1265\n', '1265\n', '1265\n', '1265\n', '1265\n', '1265\n', '1266\n', '1266\n', '1267\n', '1266\n', '1266\n', '1265\n', '1265\n', '1265\n', '1264\n', '1264\n', '1264\n', '1265\n', '1265\n', '1266\n', '1266\n', '1267\n', '1266\n', '1266\n', '1266\n', '1266\n', '1266\n', '1266\n', '1266\n', '1266\n', '1267\n', '1267\n', '1267\n', '1267\n', '1267\n', '1267\n', '1267\n', '1266\n', '1266\n', '1267\n', '1267\n', '1268\n', '1268\n', '1268\n', '1268\n', '1268\n', '1269\n', '1269\n', '1269\n', '1268\n', '1268\n', '1268\n', '1268\n', '1268\n', '1268\n', '1268\n', '1269\n', '1269\n', '1270\n', '1270\n', '1270\n', '1270\n', '1270\n', '1271\n', '1271\n', '1270\n', '1270\n', '1269\n', '1269\n', '1269\n', '1270\n', '1270\n', '1270\n', '1270\n', '1270\n', '1271\n', '1271\n', '1271\n', '1271\n', '1271\n', '1271\n', '1271\n', '1271\n', '1271\n', '1271\n', '1270\n', '1270\n', '1270\n', '1271\n', '1271\n', '1271\n', '1271\n', '1271\n', '1271\n', '1271\n', '1271\n', '1270\n', '1270\n', '1270\n', '1270\n', '1270\n', '1270\n', '1270\n', '1271\n', '1271\n', '1272\n', '1272\n', '1272\n', '1272\n', '1272\n', '1272\n', '1272\n', '1272\n', '1271\n', '1271\n', '1271\n', '1271\n', '1271\n', '1271\n', '1271\n', '1271\n', '1272\n', '1272\n', '1272\n', '1273\n', '1273\n', '1273\n', '1274\n', '1274\n', '1274\n', '1274\n', '1274\n', '1274\n', '1274\n', '1273\n', '1273\n', '1273\n', '1273\n', '1273\n', '1273\n', '1273\n', '1273\n', '1273\n', '1273\n', '1274\n', '1274\n', '1274\n', '1274\n', '1274\n', '1274\n', '1274\n', ...

# %% [markdown]
# #### (e.)  Access and print out the value of the TENTH element in this variable

# %%
print(list_of_str[9])
# Out:
# 1251

# %% [markdown]
# #### (f.) Evaluate and print out the number of elements in this variable

# %%
print(len(list_of_str))
# Out:
# 2880

# %% [markdown]
# #### (g.)  Can you change the value of an element in this variable?  Please show an example that demonstrates this either way.

# %%
# Yes, you can
print(list_of_str[0])
list_of_str[0] = '123456'
print(list_of_str[0])
# Out:
# 1250
#
# 123456

# %% [markdown]
# #### (h.)
# #### - We could use some list functions/methods to convert each element in this list to a numerical data type
# #### - But, this week, you've learned another way that is more suitable for reading in *numerical* data from text files, np.genfromtxt('filename')
# #### - Read in the data using this other way into a variable called *anything BUT 'xdata'*

# %%
height_data = np.genfromtxt(f"/pscratch/sd/d/dbrooks/atms517/{txt_string}", dtype=float)
print(height_data)
# Out:
# [1250. 1250. 1250. ... 1249. 1240. 1231.]

# %% [markdown]
# #### (i.)  Determine and print the type of this new variable

# %%
print(type(height_data))
print(type(height_data[0]))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.float64'>

# %% [markdown]
# #### (j.)  Create a 1D line plot of this tidal height data!  Specifically, you must:
# - Use the x-values I created for you in the new variable xdata (tidal height data were collected every 30 seconds, from 00:00:00 to 23:59:30). Know that this time data is in hours, and is in LOCAL time.
# - Include informative x and y axis labels and a title
# - Specify a color for the line - your choice which!
# <br><br>
# - *Keep in mind that passing the x-values into plt.plot in general is optional...if you don't, and only pass in y-values, Matplotlib will create its own x-values based on observation #.*

# %%
# 30 seconds = 1/120 of an hour
xdata = np.arange(0,24,1/120)

# Figure plot
fig = plt.figure()
ax = plt.axes()

ax.plot(xdata,height_data/100, color='b')
ax.set_ylabel('Tidal Height (m)')
ax.set_xlabel('Hour of Day (Local Time)')
ax.grid(True, alpha=0.5)
ax.set_title('Tidal Height at SYWOA Station, Antarctica\n December 26, 2004')
# Out:
# Text(0.5, 1.0, 'Tidal Height at SYWOA Station, Antarctica\n December 26, 2004')

# %% [markdown]
# # Question 2:  Creating a dictionary
# #### (a.)  Use the annual average data for Urbana, IL contained in the table linked below to create a dictionary in Python
# - For your reference, T_high is average high temperature, and T_low is average low temperature, both in degrees F.  Average precipitation and snowfall are both in inches.  (You do not need to include units in your dictionary).
#
# https://drive.google.com/file/d/1zjdXeG61cJ-GdhmAkU-EH_JPztmzr3XO/view?usp=sharing

# %%
t_dict={'T_high': 61.7,
        'T_low': 41.7,
        'Precip': 41.4,
        'Snow': 23.2}

# %% [markdown]
# #### (b.)  In one line of code, print out only ALL *values* in your dictionary

# %%
print(list(t_dict.values()))
# Out:
# [61.7, 41.7, 41.4, 23.2]

# %% [markdown]
# #### (c.) Print out just the ONE *value* in your dictionary associated with 'Precip'

# %%
print(t_dict['Precip'])
# Out:
# 41.4

# %% [markdown]
# # Question 3:  Install Python packages necessary for this class, if they aren't already installed, on whatever Python platform you are using
# - see 'Python, Statistics,  & Data Science Resources' tab on Moodle for links if you want more information on specific packages
# - see 'Basics of Packages and Syntax" in Week 2 Lessons for tips on installing Python packages
# - post on Slack or email me if you run into errors you can't solve after searching on Google/StackOverflow
#
# *Packages include*
# - numpy
# - matplotlib
# - scipy
# - sklearn
# - seaborn
# - pandas
# - xarray
# - cartopy
#
# #### Cartopy and xarray in particular can be tricky to install.  Here are some intstructions to follow:
#
# - Xarray: https://docs.xarray.dev/en/stable/getting-started-guide/installing.html#instructions
# - Cartopy: https://scitools.org.uk/cartopy/docs/latest/installing.html#conda-pre-built-binaries
#
# #### Prove your successfull installation by running the cell below with no errors & a blank map produced (cartopy notoriously has the most issues, so we'll actually test producing a map using it, too)

# %%
# Attest in this block that you have completed this
# Don't forget to use start your line with #
# As this is a code block!

import numpy
import scipy
import sklearn
import seaborn
import pandas
import xarray
import cartopy.crs as ccrs
import matplotlib.pyplot as plt

ax = plt.axes(projection=ccrs.PlateCarree())
ax.coastlines()

plt.show()

# Everything has been installed :)

# %% [markdown]
# # Question 4: Start looking for a dataset that you'd potentially want to do your project on, and then submit, here, a few sentence description of ONE dataset that you identify, as well as the website link (or an additional description if it's not publicly accessible, i.e., if it's lab group data).
#
# # Some requirements, so that you could realistically use this dataset for your project:
# - it should be geoscience data - weather, climate, geology, environmental, energy, oceanography, etc. data.  Being a geoscience course I do need to require this, but there are LOTS of options within the geosciences
# <br><br>
# - the two main packages we'll be using in this class are Pandas and Xarray.  Pandas is most useful for text-based, database formatted data.  Xarray is most useful for spatial data of binary formats like Netcdf (and has capabilities for some other binary formats)
# - you are NOT limited to these data formats, but when it comes to your project, you'll have to justify why you are choosing different, and identify what other Python packages you'd use to faciliate the reading in of those other types of data (e.g., radar, satellite, etc.)....and have potentially limited support from me/your peers in those other packages not covered in this class
# <br><br>
# - what you submit for this Q DOES NOT commit you to using this dataset for your project...I just want you to start brainstorming and exploring data!
#
# # Some tips and tricks for picking a dataset that will likely help you have a smoother project
#
# - Data that is already numerical or needs minimal pre-processing to get it to be numerical and useable for analyses
#     - Doing image analysis?  Do you already know how to use pre-processing software?
# <br><br>
# - Data that has many options for analysis – often, multiple ‘dimensions’/components.  Consider looking for data that has multiple different variables involved that have at LEAST one of the following:
#      - Exists at a fair number of locations
#      - Exists at a fair number of times
#      - Exists at a fair number of heights/depths
# <br><br>
# - What does "fair number" mean?
#      - At least 30-50 data points (see Project Proposal Plan under 'Data Science Project' (Milestone #1) for more details)
# <br><br>
# - Example of what might be **CHALLENGING** to do substantial analysis on: data from one time, one depth from two mines of rock compositions

# %% [markdown]
# ## Response
#
# My idea is to do something with the ERA5 Reanalysis dataset, which can be downloaded from here: https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels?tab=download. ERA5 is a 4-D gridded reanalysis dataset for global climate and weather data, based around the assmilation of ECMWF model data and observations dating back to 1940. It has a whole host of different variables you can choose from, presented at 0.25x0.25 degree spatial resolution and hourly temporal resolution. Because of its diverse list of available variables and its global spatial extent, it offers a wide range of directions I could possibly go with it. It's a dataset I have worked with very sparingly in the past, and given its prevelance in the weather and climate field (especially risk analysis), I figured this is a good opportunity to better familiarize myself with it.
